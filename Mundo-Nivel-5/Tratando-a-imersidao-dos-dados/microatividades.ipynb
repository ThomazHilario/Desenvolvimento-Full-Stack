# %%
from google.colab import files
import pandas as pd

# Micro atividade 1:

# Como estou no cola o arquivo eu busco no meu diretorio, ja que não está em um para especificar o caminho
uploaded = files.upload()
arquivo = list(uploaded.keys())[0]
df = pd.read_csv(arquivo, sep=';', engine='python', encoding='ISO-8859-1')
print(df)

print("===============================================================================")

#Micro atividade 2:
subconjunto = df[['Duration', 'Calories', 'Pulse']]

print(subconjunto)

print("===============================================================================")

#Micro atividade 3:
uploaded2 = files.upload()
arquivo2 = list(uploaded2.keys())[0]
df2 = pd.read_csv(arquivo2, sep=';', engine='python', encoding='ISO-8859-1')
pd.set_option('display.max_rows', 2)

print(df2.to_string())

print("===============================================================================")

#Micro atividade 4:
print("Primeiras 10 linhas:")
print(df.head(10))

print("\nÚltimas 10 linhas:")
print(df.tail(10))

print("===============================================================================")

#Micro atividade 5:
print("Informações gerais sobre o dataframe:")
print(df.info())

print("\nDados nulos por coluna:")
print(df.isnull().sum())

print("\nTipos de dados por coluna:")
print(df.dtypes)

print("\nMemória utilizada pelo dataframe:")
print(df.memory_usage(deep=True))
# Out:
#      <input type="file" id="files-1bacfac3-02b1-41ca-b345-4d5290e1545c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bacfac3-02b1-41ca-b345-4d5290e1545c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
